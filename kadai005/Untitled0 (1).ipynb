# %%
print(1+1)
# Out:
# 2

# %%
print(45 + 18)
print(30 - 12)
print(15 * 6)
print(30 / 3)
print(45 % 8)
# Out:
# 63
# 18
# 90
# 10.0
# 5

# %%
print(type(30 / 3))
# Out:
# <class 'float'>

# %%
print("今日の天気は" + "晴れ")
print("今日の天気は" "曇り")
# Out:
# 今日の天気は晴れ
# 今日の天気は曇り

# %%
print("降水確率" + str(50) + "%")
# Out:
# 降水確率50%

# %%
print("晴れ" * 5)
# Out:
# 晴れ晴れ晴れ晴れ晴れ

# %%
user_name = "侍太郎"
print(user_name)
# Out:
# 侍太郎

# %%
user_name = "侍太郎"
print(user_name)
user_name = "侍花子"
print(user_name)
# Out:
# 侍太郎
# 侍花子

# %%
number1 = 5
number2 = 2.5
print(number1 + number2)
# Out:
# 7.5

# %%
last_name = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 侍太郎

# %%
last_name = "侍"
first_name = "太郎"
sister_name = "花子"
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。

# %%
new_var = print((10 + 20) * 5 / 2, "㎠")
new_var
# Out:
# 75.0 ㎠

# %%
upper_base = 10
lower_base = 20
height = 5
trapezoid_area = (upper_base + lower_base) * height / 2
print(trapezoid_area, "㎠")
# Out:
# 75.0 ㎠

# %%
upper_base = 10
lower_base = 20
height = 5
trapezoid_area = (upper_base + lower_base) * height / 2
print(trapezoid_area, "㎠")
# Out:
# 75.0 ㎠

# %%
mkdir kadai_005

# %%
cd kadai_005/
git init
# Out:
#   File "<ipython-input-20-c80057b1ea07>", line 1
#     cd kadai_005/
#        ^
# SyntaxError: invalid syntax

# %%
git init
# Out:
#   File "<ipython-input-21-f188d5ac1197>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
print(((10 + 20) * 5 / 2) + "㎠")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a2cd02e1f595> in <cell line: 0>()
# ----> 1 print(((10 + 20) * 5 / 2) + "㎠")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print("今日の天気は" + "晴れ")
