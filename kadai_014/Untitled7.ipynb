# %%
def calculate_total(price,tax):

  total = (price * tax / 100) + price

  return total

calculate_total(110,10)
# Out:
# 121.0

# %%
price1 = 100
price2 = 200

def total():

    tax = 1.1
    return price1 + price2
tax = 1.1

print (total() * tax)
# Out:
# 330.0
